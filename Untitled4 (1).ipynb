# %%
import logging

logging.basicConfig(filename="q23_file_errors.log",
                    level=logging.ERROR,
                    format="%(asctime)s %(levelname)s %(message)s")

filename = "q23_missing.txt"

try:
    with open(filename, "r") as f:
        print(f.read())
except OSError as e:
    logging.error("Error handling file %s: %s", filename, e)
    print("File error logged to q23_file_errors.log")

# %% [markdown]
# File error logged to q23_file_errors.log
